# %%
pwd
# Out:
# '/home/tianyushi/code/COMP551-project/2/code/lstm-exp-hyperparameter'

# %%
import pickle

accs=pickle.load(open("accs_epoch_new","rb"))

# %%
epochs=[]
for epo in range(1,60,3):
    epochs.append(epo)

# %%
import matplotlib.pyplot as plt
plt.plot(epochs,accs)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.savefig('epoch_new.pdf')

# %%
print(accs)
# Out:
# [0.891679999961853, 0.8856400000190735, 0.863960000038147, 0.8397199999809265, 0.8650399999809265, 0.872160000038147, 0.8708799999618531, 0.871959999961853, 0.8642800000190735, 0.8682799999809265, 0.8626000000190734, 0.8671999999809266, 0.869040000038147, 0.8677200000190735, 0.86844, 0.8566800000190735, 0.8729199999809265, 0.86212, 0.8655599999618531, 0.86676]

# %%
print(epochs)
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58]
